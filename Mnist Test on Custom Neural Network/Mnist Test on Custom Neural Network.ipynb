# %%
import DeepNeuralNetwork as DNN
import numpy as np
from mlxtend.data import loadlocal_mnist
import matplotlib.pyplot as plt
from keras.utils import to_categorical

# %%
x_train, y_train = loadlocal_mnist(images_path='C:/Users/Muhammad Darab/OneDrive/Desktop/Online Course Files/Machine Learning/Data Sets/NeuralNetwork-LogisticsDigits/train-images.idx3-ubyte', labels_path='C:/Users/Muhammad Darab/OneDrive/Desktop/Online Course Files/Machine Learning/Data Sets/NeuralNetwork-LogisticsDigits/train-labels.idx1-ubyte')
x_test, y_test = loadlocal_mnist(images_path='C:/Users/Muhammad Darab/OneDrive/Desktop/Online Course Files/Machine Learning/Data Sets/NeuralNetwork-LogisticsDigits/t10k-images.idx3-ubyte', labels_path='C:/Users/Muhammad Darab/OneDrive/Desktop/Online Course Files/Machine Learning/Data Sets/NeuralNetwork-LogisticsDigits/t10k-labels.idx1-ubyte')
x_train = x_train[:10000]
y_train = y_train[:10000]
x_test = x_test[:7000]
y_test = y_test[:7000]
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
layer_dims = [784, 720, 360, 10]
activations = ['sigmoid', 'sigmoid', 'sigmoid']
keep_probs = [0.5, 0.5]
epochs = 1000
mini_batch_size = 512
time_interval = 50
learning_rate_init = 0.005
decay_rate = 1
initialization = True
beta_1 = 0.9
beta_2 = 0.999
epsilon = 1e-8

# %%
parameters = DNN.neural_network(x_train.T, y_train.T, epochs, mini_batch_size, time_interval, layer_dims, activations, learning_rate_init, decay_rate, keep_probs, initialization, beta_1 , beta_2, epsilon)
DNN.test_set_prediction(x_test.T, y_test.T, layer_dims, parameters, activations)
# Out:
# C:\Users\Muhammad Darab\AppData\Local\Programs\Python\Python310\lib\site-packages\DeepNeuralNetwork.py:53: RuntimeWarning: overflow encountered in exp
#   A = (1 / (1 + np.exp(-Z)))
# C:\Users\Muhammad Darab\AppData\Local\Programs\Python\Python310\lib\site-packages\DeepNeuralNetwork.py:176: RuntimeWarning: overflow encountered in exp
#   s = (1 / (1 + np.exp(-Z)))
# Cost after 0 epochs is 0.007139884046258986
# Cost after 5 epochs is 0.00250965435626429
# Cost after 10 epochs is 0.0018550500732681385
# Cost after 15 epochs is 0.001544712987643259
# Cost after 20 epochs is 0.0013369631709516253
# Cost after 25 epochs is 0.0012616683239589275
# Cost after 30 epochs is 0.001203913381960569
# Cost after 35 epochs is 0.0011336314844917455
# Cost after 40 epochs is 0.0010549620943841329
# Cost after 45 epochs is 0.0010282150065255029
# Cost after 50 epochs is 0.0009633124790152102
# Cost after 55 epochs is 0.0008885490297676739
# Cost after 60 epochs is 0.0008640336039439155
# Cost after 65 epochs is 0.0008546801565752876
# Cost after 70 epochs is 0.0007955229788173708
# Cost after 75 epochs is 0.0007874431141197108
# Cost after 80 epochs is 0.0007792624083691675
# Cost after 85 epochs is 0.0007427099277175041
# Cost after 90 epochs is 0.0007411640324636314
# Cost after 95 epochs is 0.0006941011039469931
# Cost after 100 epochs is 0.0007034305782949274
# Cost after 105 epochs is 0.0006304001523722006
# Cost after 110 epochs is 0.000652080143092137
# Cost after 115 epochs is 0.0006225501336432487
# Cost after 120 epochs is 0.0006342665473535326
# Cost after 125 epochs is 0.0006081464273033376
# Cost after 130 epochs is 0.0005876416615467509
# Cost after 135 epochs is 0.0005868683018492418
# Cost after 140 epochs is 0.0005596890692712625
# Cost after 145 epochs is 0.0005644522381864452
# Cost after 150 epochs is 0.0005387158025212146
# Cost after 155 epochs is 0.0005225014964168466
# Cost after 160 epochs is 0.0005509717547899877
# Cost after 165 epochs is 0.0005424520516836529
# Cost after 170 epochs is 0.0005124181574714413
# Cost after 175 epochs is 0.0004927229517954066
# Cost after 180 epochs is 0.0004895539595616569
# Cost after 185 epochs is 0.0004916998759211999
# Cost after 190 epochs is 0.0004739690895830956
# Cost after 195 epochs is 0.0004808732127406036
# Cost after 200 epochs is 0.000493172715046233
# Cost after 205 epochs is 0.00044655744511680695
# Cost after 210 epochs is 0.0004443860185260162
# Cost after 215 epochs is 0.00043284475877270194
# Cost after 220 epochs is 0.0004254590055528277
# Cost after 225 epochs is 0.000433430684590596
# Cost after 230 epochs is 0.0004166909186938557
# Cost after 235 epochs is 0.0004219914805767914
# Cost after 240 epochs is 0.00040793441302180755
# Cost after 245 epochs is 0.00038632217956348266
# Cost after 250 epochs is 0.000401342636003017
# Cost after 255 epochs is 0.0003907354261006335
# Cost after 260 epochs is 0.00038828788131009496
# Cost after 265 epochs is 0.00039166742092958
# Cost after 270 epochs is 0.00038234246615228293
# Cost after 275 epochs is 0.0003697165119913043
# Cost after 280 epochs is 0.0003654096831148505
# Cost after 285 epochs is 0.00034923752646194003
# Cost after 290 epochs is 0.0003552633517284486
# Cost after 295 epochs is 0.00036533001764504127
# Cost after 300 epochs is 0.0003509151443943277
# Cost after 305 epochs is 0.0003605274793295995
# Cost after 310 epochs is 0.0003437009541426273
# Cost after 315 epochs is 0.00033777418302920924
# Cost after 320 epochs is 0.00031570154208004203
# Cost after 325 epochs is 0.0003452803369817838
# Cost after 330 epochs is 0.00032590099955246
# Cost after 335 epochs is 0.00032407008802967093
# Cost after 340 epochs is 0.0003119038111053063
# Cost after 345 epochs is 0.00029234153998168393
# Cost after 350 epochs is 0.0003113345070981211
# Cost after 355 epochs is 0.0003365414947738855
# Cost after 360 epochs is 0.00030644987058306444
# Cost after 365 epochs is 0.0003146629036870525
# Cost after 370 epochs is 0.0002936722018059519
# Cost after 375 epochs is 0.0003020051750825616
# Cost after 380 epochs is 0.00029909584442461783
# Cost after 385 epochs is 0.0002668284699517464
# Cost after 390 epochs is 0.0002761632387091759
# Cost after 395 epochs is 0.0002780710001778376
# Cost after 400 epochs is 0.000282265887083337
# Cost after 405 epochs is 0.00026032568256055853
# Cost after 410 epochs is 0.00025565507761433036
# Cost after 415 epochs is 0.0002680207154589425
# Cost after 420 epochs is 0.0002806410194878055
# Cost after 425 epochs is 0.00024203743095594236
# Cost after 430 epochs is 0.0002496571222033907
# Cost after 435 epochs is 0.0002518089974208691
# Cost after 440 epochs is 0.0002505417041950363
# Cost after 445 epochs is 0.00026364715850159666
# Cost after 450 epochs is 0.00022746072750224098
# Cost after 455 epochs is 0.00023408111631808906
# Cost after 460 epochs is 0.0002351029108840324
# Cost after 465 epochs is 0.0002387516956660065
# Cost after 470 epochs is 0.0002481402705351616
# Cost after 475 epochs is 0.00023390521301747293
# Cost after 480 epochs is 0.0002288521720939047
# Cost after 485 epochs is 0.00024234073253363958
# Cost after 490 epochs is 0.00022929980398600177
# Cost after 495 epochs is 0.0002407104644470999
# Cost after 500 epochs is 0.00023073894042533794
# Cost after 505 epochs is 0.00022719361176011516
# Cost after 510 epochs is 0.000212668012504264
# Cost after 515 epochs is 0.00021337441073645817
# Cost after 520 epochs is 0.00022346700659448362
# Cost after 525 epochs is 0.00021317657244747105
# Cost after 530 epochs is 0.00021690546818596367
# Cost after 535 epochs is 0.00021134866101408525
# Cost after 540 epochs is 0.00020953150166500318
# Cost after 545 epochs is 0.00022800240864848678
# Cost after 550 epochs is 0.00020878853614455465
# Cost after 555 epochs is 0.0002081635076605043
# Cost after 560 epochs is 0.00020367397830225995
# Cost after 565 epochs is 0.0001919505922786881
# Cost after 570 epochs is 0.00019218009124413578
# Cost after 575 epochs is 0.00019143383768233422
# Cost after 580 epochs is 0.00017443740279939507
# Cost after 585 epochs is 0.0001884917365192708
# Cost after 590 epochs is 0.00018557172972971355
# Cost after 595 epochs is 0.00017726260515006363
# Cost after 600 epochs is 0.00018157507378392565
# Cost after 605 epochs is 0.00019311127263245254
# Cost after 610 epochs is 0.00018234919495010318
# Cost after 615 epochs is 0.00018244817638266584
# Cost after 620 epochs is 0.00017684322521474476
# Cost after 625 epochs is 0.0001769318021355218
# Cost after 630 epochs is 0.0001913669430317798
# Cost after 635 epochs is 0.000181579998398763
# Cost after 640 epochs is 0.00018234489817749419
# Cost after 645 epochs is 0.00018802219709421178
# Cost after 650 epochs is 0.00018601802988945225
# Cost after 655 epochs is 0.00017087568705729264
# Cost after 660 epochs is 0.00017614376567365867
# Cost after 665 epochs is 0.00017042084171185377
# Cost after 670 epochs is 0.0001691813970739584
# Cost after 675 epochs is 0.00016839942788837803
# Cost after 680 epochs is 0.00017443966109817114
# Cost after 685 epochs is 0.00016047417057405276
# Cost after 690 epochs is 0.00015716816872472688
# Cost after 695 epochs is 0.00018480333458648107
# Cost after 700 epochs is 0.00015160602293381884
# Cost after 705 epochs is 0.00016433625180983945
# Cost after 710 epochs is 0.00016464531348155893
# Cost after 715 epochs is 0.0001594357568844034
# Cost after 720 epochs is 0.0001690064147392543
# Cost after 725 epochs is 0.00015763710873320803
# Cost after 730 epochs is 0.00015746855973267418
# Cost after 735 epochs is 0.00013960892940628
# Cost after 740 epochs is 0.00017122580599975088
# Cost after 745 epochs is 0.00015108569456613399
# Cost after 750 epochs is 0.00015270979967593577
# Cost after 755 epochs is 0.00013738097525436272
# Cost after 760 epochs is 0.00014316008801954852
# Cost after 765 epochs is 0.00014728585025277136
# Cost after 770 epochs is 0.000146790025037432
# Cost after 775 epochs is 0.00013929282734661915
# Cost after 780 epochs is 0.00015322026646905296
# Cost after 785 epochs is 0.00015627015444113994
# Cost after 790 epochs is 0.00013807632032086282
# Cost after 795 epochs is 0.00014893444982150218
# Cost after 800 epochs is 0.0001470835636959072
# Cost after 805 epochs is 0.00014344079880532256
# Cost after 810 epochs is 0.00014032610574886813
# Cost after 815 epochs is 0.00013372605216322876
# Cost after 820 epochs is 0.00013222910317599844
# Cost after 825 epochs is 0.0001330995736417596
# Cost after 830 epochs is 0.000135669478203179
# Cost after 835 epochs is 0.00015041802183176327
# Cost after 840 epochs is 0.00013254825200780974
# Cost after 845 epochs is 0.00013018606324586223
# Cost after 850 epochs is 0.00013227093462697502
# Cost after 855 epochs is 0.00013871065737748457
# Cost after 860 epochs is 0.0001302708647519403
# Cost after 865 epochs is 0.00013377772812119262
# Cost after 870 epochs is 0.0001361314222394913
# Cost after 875 epochs is 0.00012993242790038158
# Cost after 880 epochs is 0.00012620582369263868
# Cost after 885 epochs is 0.00014109564077096915
# Cost after 890 epochs is 0.0001323760532366216
# Cost after 895 epochs is 0.0001417163402983436
# Cost after 900 epochs is 0.00012508853568544637
# Cost after 905 epochs is 0.0001283028413475945
# Cost after 910 epochs is 0.00012756002209789286
# Cost after 915 epochs is 0.00012647360142293535
# Cost after 920 epochs is 0.00012587245856410286
# Cost after 925 epochs is 0.0001396860116077853
# Cost after 930 epochs is 0.0001291836871010362
# Cost after 935 epochs is 0.00010824193758565886
# Cost after 940 epochs is 0.00013226249099880755
# Cost after 945 epochs is 0.00011882130683169308
# Cost after 950 epochs is 0.00011664789861401872
# Cost after 955 epochs is 0.00011738114716176558
# Cost after 960 epochs is 0.00012107949256184234
# Cost after 965 epochs is 0.00010829023422030275
# Cost after 970 epochs is 0.00011479648657666134
# Cost after 975 epochs is 0.00010573126472601812
# Cost after 980 epochs is 0.00012161947223156347
# Cost after 985 epochs is 9.979331847251997e-05
# Cost after 990 epochs is 0.00011115930068476143
# Cost after 995 epochs is 0.00011361069082922987
# Cost after 999 epochs is 0.0001186589573377128
# C:\Users\Muhammad Darab\AppData\Local\Programs\Python\Python310\lib\site-packages\DeepNeuralNetwork.py:53: RuntimeWarning: overflow encountered in exp
#   A = (1 / (1 + np.exp(-Z)))
# [5. 0. 4. ... 6. 9. 7.] [5. 0. 4. ... 6. 9. 7.]
# The accuracy of the model on Training Set is 99.21 %
# The accuracy of the model on Test Set is 94.91428571428571 %
